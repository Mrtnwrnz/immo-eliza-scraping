# %%
import requests
from bs4 import BeautifulSoup
import csv

list_1 = ["https://www.immoweb.be/nl/zoekertje/huis/te-koop/wenduine/8420/1882546",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/kapellen/2950/2070520",
"https://www.immoweb.be/nl/zoekertje/appartement/te-koop/geel/2440/2573581",
"https://www.immoweb.be/nl/zoekertje/appartement/te-koop/tessenderlo/3980/2573644",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/heist-aan-zee/8301/2784938",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/s-gravenwezel/2970/3303247",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/ingelmunster/8770/3622649",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/st-ulriks-kapelle/1700/3779703",
"https://www.immoweb.be/nl/zoekertje/appartement/te-koop/schaerbeek/1030/3829592",
"https://www.immoweb.be/nl/zoekertje/appartement/te-koop/knokke/8300/3841346",
"https://www.immoweb.be/nl/zoekertje/appartement/te-koop/knokke/8300/3841347",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/schoten/2900/3903180",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/schoten-koningshof/2900/3947116",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/ingelmunster/8770/3956676",
"https://www.immoweb.be/nl/zoekertje/appartement/te-koop/oostende/8400/4079236",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/gent/9000/4089845",
"https://www.immoweb.be/nl/zoekertje/appartement/te-koop/borgerhout/2140/4132492",
"https://www.immoweb.be/nl/zoekertje/appartement/te-koop/oostende/8400/4183567",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/s-gravenwezel/2970/4329019",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/ternat/1740/4503569",
"https://www.immoweb.be/nl/zoekertje/appartement/te-koop/st-gilles/1060/4611027",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/ruddervoorde/8020/4614118",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/assebroek/8310/4614119",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostende/8400/4679861",
"https://www.immoweb.be/nl/zoekertje/appartement/te-koop/oostende/8400/4679862",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/schilde/2970/4711417",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/schoten/2900/4718207",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725060",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725061",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725062",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725063",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725064",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725065",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725066",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725067",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725068",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725069",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725070",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725071",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725072",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725073",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725074",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725075",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725076",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725077",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725078",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725079",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725080",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725081",
"https://www.immoweb.be/nl/zoekertje/huis/te-koop/oostduinkerke/8670/4725082"]

def get_soup(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html")
    return soup

def get_data(soup, url):
    data_dict = {}
    url_split = url.split("/")
    # add price
    price_element = soup.find("p", attrs={"class": "classified__price"})
    if price_element:
        price = price_element.text.split(" ")[-1].strip()
        if price[-1] == "€":
            price = price[:-1]
        data_dict["price"] = price
    else:
        data_dict["price"] = ''
    # add data from url
    data_dict["property_id"] = url_split[-1]
    data_dict["postal_code"] = url_split[-2]
    data_dict["locality_name"] = url_split[-3]
    data_dict["property_subtype"] = url_split[-5]
    # add all data from classified table
    rows = soup.find_all('tr', class_='classified-table__row')
    for row in rows:
        header = row.find('th', class_='classified-table__header')
        data_cell = row.find('td', class_='classified-table__data')
        if header and data_cell:
            header_key = header.contents[0].strip()
            data_cell_value = data_cell.contents[0].strip()
        else:
            pass
        data_dict[header_key] = data_cell_value
    return data_dict

def get_rooms(data_dict):
    rooms = 0
    if 'Oppervlakte woonkamer' in data_dict.keys():
        rooms +=1
    if 'Oppervlakte keuken' in data_dict.keys():
        rooms +=1
    if 'Slaapkamers' in data_dict.keys():
        rooms += int(data_dict['Slaapkamers'])
    if 'Badkamers' in data_dict.keys():
        rooms += int(data_dict['Badkamers'])
    if 'Kelder' in data_dict.keys():
        rooms +=1
    data_dict['rooms'] = rooms
    return data_dict

def attempt(url):
    soup_file = get_soup(url)
    extract = get_data(soup_file, url)
    all_data = get_rooms(extract)
    return all_data


list_raw_1 = []
for i in list_1:
    list_raw_1.append(attempt(i))


# remove dictionaries with life sales
list_raw_1 = [d for d in list_raw_1 if 'Maandelijkse rente' not in d]
# Remove dictionaries without price value (=sold)
list_raw_1 = [d for d in list_raw_1 if d.get('price')]
# remove all keys except for 17 must-haves
columns = ['property_type', 'price', 'property_id', 'postal_code', 'locality_name', 'property_subtype', 'Staat van het gebouw', 'Aantal gevels', 'Bewoonbare oppervlakte', 'Type keuken', 'Oppervlakte tuin', 'Oppervlakte terras', 'Gemeubeld', 'Aantal open haarden', 'Zwembad', 'rooms', 'sale_type']
list_raw_1 = [{key: value for key, value in d.items() if key in columns} for d in list_raw_1]
# remove keys with empty values ('Niet gespecificeerd', '')
list_raw_1 = [{key: value for key, value in d.items() if value not in ('', 'Niet gespecificeerd')} for d in list_raw_1]
# replace values 'Ja' with '1', and 'Nee' with '0'
list_raw_1 = [{key: (True if value == 'Ja' else value) for key, value in d.items()} for d in list_raw_1]
list_raw_1 = [{key: (False if value == 'Nee' else value) for key, value in d.items()} for d in list_raw_1]
# Setting specified values to True/False
list_raw_1 = [{
        **d,  # Keep all existing key-value pairs
        'Aantal open haarden': d.get('Aantal open haarden', 0) != 0,
        'Zwembad': d.get('Zwembad', 'Nee') == 'Ja',
        'Type keuken': len(d.get('Type keuken', '')) > 3,
        'Gemeubeld': d.get('Gemeubeld', 'Nee') == 'Ja'
    } for d in list_raw_1]
# setting specified values to null if not present
list_raw_1 = [{
        **d,
        **{key: d.get(key, 'null') for key in ['Oppervlakte tuin', 'Oppervlakte terras']}} for d in list_raw_1]


# Collect all unique keys for columns
all_keys = set()
for i in list_raw_1:
    all_keys.update(i.keys())
# Write dictionaries to CSV
with open('output1.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=sorted(all_keys))
    writer.writeheader()
    for i in list_raw_1:
        writer.writerow(i)
